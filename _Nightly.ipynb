# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Stop-Reinventing-Pandas" data-toc-modified-id="Stop-Reinventing-Pandas-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Stop Reinventing Pandas</a></span></li><li><span><a href="#First-Hacks!" data-toc-modified-id="First-Hacks!-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>First Hacks!</a></span><ul class="toc-item"><li><span><a href="#Beautiful-pipes!" data-toc-modified-id="Beautiful-pipes!-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Beautiful pipes!</a></span></li><li><span><a href="#The-Penny-Drops" data-toc-modified-id="The-Penny-Drops-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>The Penny Drops</a></span></li><li><span><a href="#Map-with-dict" data-toc-modified-id="Map-with-dict-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Map with dict</a></span></li></ul></li><li><span><a href="#Time-Series" data-toc-modified-id="Time-Series-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Time Series</a></span><ul class="toc-item"><li><span><a href="#Resample" data-toc-modified-id="Resample-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Resample</a></span><ul class="toc-item"><li><span><a href="#The-Old-Way" data-toc-modified-id="The-Old-Way-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>The Old Way</a></span></li><li><span><a href="#A-Better-Way" data-toc-modified-id="A-Better-Way-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>A Better Way</a></span></li></ul></li><li><span><a href="#Slice-Easily" data-toc-modified-id="Slice-Easily-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Slice Easily</a></span></li><li><span><a href="#Time-Windows:-Rolling,-Expanding,-EWM" data-toc-modified-id="Time-Windows:-Rolling,-Expanding,-EWM-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Time Windows: Rolling, Expanding, EWM</a></span><ul class="toc-item"><li><span><a href="#With-Apply" data-toc-modified-id="With-Apply-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>With Apply</a></span></li></ul></li><li><span><a href="#Combine-with-GroupBy-🤯" data-toc-modified-id="Combine-with-GroupBy-🤯-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Combine with GroupBy 🤯</a></span></li></ul></li><li><span><a href="#Sorting" data-toc-modified-id="Sorting-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Sorting</a></span><ul class="toc-item"><li><span><a href="#By-Values" data-toc-modified-id="By-Values-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>By Values</a></span></li><li><span><a href="#By-Index" data-toc-modified-id="By-Index-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>By Index</a></span></li><li><span><a href="#By-Both-(New-in-0.23)" data-toc-modified-id="By-Both-(New-in-0.23)-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>By Both <span style="color: red">(New in 0.23)</span></a></span></li></ul></li><li><span><a href="#Stack,-Unstack" data-toc-modified-id="Stack,-Unstack-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Stack, Unstack</a></span><ul class="toc-item"><li><span><a href="#Unstack" data-toc-modified-id="Unstack-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Unstack</a></span><ul class="toc-item"><li><span><a href="#The-Old-way" data-toc-modified-id="The-Old-way-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>The Old way</a></span></li><li><span><a href="#A-better-way" data-toc-modified-id="A-better-way-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>A better way</a></span></li></ul></li><li><span><a href="#Unstack" data-toc-modified-id="Unstack-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Unstack</a></span><ul class="toc-item"><li><span><a href="#Some-More-Hacks" data-toc-modified-id="Some-More-Hacks-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Some More Hacks</a></span></li></ul></li></ul></li><li><span><a href="#GroupBy" data-toc-modified-id="GroupBy-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>GroupBy</a></span><ul class="toc-item"><li><span><a href="#Old-Ways" data-toc-modified-id="Old-Ways-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Old Ways</a></span><ul class="toc-item"><li><span><a href="#List-Aggregates" data-toc-modified-id="List-Aggregates-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>List Aggregates</a></span></li><li><span><a href="#Dict-aggregate" data-toc-modified-id="Dict-aggregate-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>Dict aggregate</a></span></li><li><span><a href="#With-Rename" data-toc-modified-id="With-Rename-6.1.3"><span class="toc-item-num">6.1.3&nbsp;&nbsp;</span>With Rename</a></span></li></ul></li><li><span><a href="#Named-Aggregations-(New-in-0.25)" data-toc-modified-id="Named-Aggregations-(New-in-0.25)-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Named Aggregations <span style="color: red">(New in 0.25)</span></a></span></li></ul></li><li><span><a href="#Clip" data-toc-modified-id="Clip-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Clip</a></span><ul class="toc-item"><li><span><a href="#The-Old-Way" data-toc-modified-id="The-Old-Way-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>The Old Way</a></span></li><li><span><a href="#A-better-way" data-toc-modified-id="A-better-way-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>A better way</a></span></li></ul></li><li><span><a href="#Reindex" data-toc-modified-id="Reindex-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Reindex</a></span></li><li><span><a href="#Method-Chaining" data-toc-modified-id="Method-Chaining-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Method Chaining</a></span><ul class="toc-item"><li><span><a href="#Assign" data-toc-modified-id="Assign-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Assign</a></span><ul class="toc-item"><li><span><a href="#With-a-callable" data-toc-modified-id="With-a-callable-9.1.1"><span class="toc-item-num">9.1.1&nbsp;&nbsp;</span>With a callable</a></span></li></ul></li><li><span><a href="#Pipe" data-toc-modified-id="Pipe-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Pipe</a></span></li></ul></li><li><span><a href="#Beautiful-Code-Tells-a-Story" data-toc-modified-id="Beautiful-Code-Tells-a-Story-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Beautiful Code Tells a Story</a></span></li><li><span><a href="#Bonus!" data-toc-modified-id="Bonus!-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Bonus!</a></span><ul class="toc-item"><li><span><a href="#Percent-Change" data-toc-modified-id="Percent-Change-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>Percent Change</a></span></li><li><span><a href="#Interval-Index" data-toc-modified-id="Interval-Index-11.2"><span class="toc-item-num">11.2&nbsp;&nbsp;</span>Interval Index</a></span></li><li><span><a href="#Split-Strings" data-toc-modified-id="Split-Strings-11.3"><span class="toc-item-num">11.3&nbsp;&nbsp;</span>Split Strings</a></span></li><li><span><a href="#Toy-Examples-with-Pandas-Testing" data-toc-modified-id="Toy-Examples-with-Pandas-Testing-11.4"><span class="toc-item-num">11.4&nbsp;&nbsp;</span>Toy Examples with Pandas Testing</a></span></li></ul></li><li><span><a href="#Research-with-Style!" data-toc-modified-id="Research-with-Style!-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Research with Style!</a></span><ul class="toc-item"><li><span><a href="#Basic" data-toc-modified-id="Basic-12.1"><span class="toc-item-num">12.1&nbsp;&nbsp;</span>Basic</a></span></li><li><span><a href="#Gradient" data-toc-modified-id="Gradient-12.2"><span class="toc-item-num">12.2&nbsp;&nbsp;</span>Gradient</a></span></li><li><span><a href="#Custom" data-toc-modified-id="Custom-12.3"><span class="toc-item-num">12.3&nbsp;&nbsp;</span>Custom</a></span></li><li><span><a href="#Bars" data-toc-modified-id="Bars-12.4"><span class="toc-item-num">12.4&nbsp;&nbsp;</span>Bars</a></span></li></ul></li><li><span><a href="#You-don't-have-to-memorize-this" data-toc-modified-id="You-don't-have-to-memorize-this-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>You don't have to memorize this</a></span></li><li><span><a href="#Resources" data-toc-modified-id="Resources-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>Resources</a></span></li></ul></div>

# %% [markdown]
# # Stop Reinventing Pandas

# %% [markdown]
# The following post was presented as a talk for the [IE@DS](https://www.facebook.com/groups/173376299978861/) community, and for the [PyData meetup](https://www.meetup.com/PyData-Tel-Aviv/events/256232456/).
# All the resources for this post, including a runable notebook, can be found in the [github repo](https://github.com/DeanLa/dont_reinvent_pandas)
# blog post version here:
#
#
# <span style="font-size:2em"> [DeanLa.com](http://deanla.com/)</span>

# %% [markdown]
# ![slide1](slides/slide1.jpg)

# %% [markdown]
# This notebook aims to show some nice ways modern Pandas makes your life easier. It is not about efficiency. I'm Pandas' built-in methods will be more efficient than reinventing pandas, but the main goal is to make the code easier to read, and more imoprtant - easier to write.

# %% [markdown]
# ![slide3](slides/slide3.jpg)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use(['classic', 'ggplot', 'seaborn-poster', 'dean.style'])
# %load_ext autoreload
# %autoreload 2
import my_utils
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# # First Hacks!

# %% [markdown]
# Reading the data and a few housekeeping tasks. is the first place we can make our code more readable.

# %%
df_io = pd.read_csv('./bear_data.csv', index_col=0, parse_dates=['date_'])
df_io.head()
# Out:
#                         val_updated                            date_  \
# 0  2018-10-09 17:01:30.662390+00:00 2018-10-09 17:01:30.662389+00:00
# 1  2018-10-09 17:01:30.687675+00:00 2018-10-09 17:01:30.687675+00:00
# 2  2018-10-09 17:03:23.952848+00:00 2018-10-09 17:03:23.952847+00:00
# 3  2018-10-09 17:05:42.327744+00:00 2018-10-09 17:05:42.327744+00:00
# 4  2018-09-24 16:36:38.177661+00:00 2018-10-09 17:06:29.708909+00:00
#
#    bear_type
# 0          5
# 1          5
# 2          1
# 3          7
# 4          7

# %%
df = df_io.copy().sort_values('date_').set_index('date_').drop(columns='val_updated')
df.head()
# Out:
#                                   bear_type
# date_
# 2018-10-09 17:01:30.662389+00:00          5
# 2018-10-09 17:01:30.687675+00:00          5
# 2018-10-09 17:03:23.952847+00:00          1
# 2018-10-09 17:05:42.327744+00:00          7
# 2018-10-09 17:06:29.708909+00:00          7

# %% [markdown]
# ## Beautiful pipes!
# One line method chaining is hard to read and prone to human error, chaining each method in its own line makes it a lot more readable.

# %%
df_io\
    .copy()\
    .sort_values('date_')\
    .set_index('date_')\
    .drop(columns='val_updated')\
    .head()
# Out:
#                                   bear_type
# date_
# 2018-10-09 17:01:30.662389+00:00          5
# 2018-10-09 17:01:30.687675+00:00          5
# 2018-10-09 17:03:23.952847+00:00          1
# 2018-10-09 17:05:42.327744+00:00          7
# 2018-10-09 17:06:29.708909+00:00          7

# %% [markdown]
# But it has a problem. You can't comment out and even comment in between

# %%
# This block will result in an error
df_io\
.copy()\ # This is an inline comment
# This is a regular comment
.sort_values('date_')\
# .set_index('date_')\
.drop(columns='val_updated')\ 
.head()
# Out:
#   File "<ipython-input-22-47935cfbac77>", line 3
#     .copy()\ # This is an inline comment
#                                         ^
# SyntaxError: unexpected character after line continuation character

# %% [markdown]
# Even an unnoticeable space character may break everything

# %%
# This block will result in an error
df_io\
.copy()\
.sort_values('date_')\
.set_index('date_')\
.drop(columns='val_updated')\ 
.head()
# Out:
#   File "<ipython-input-23-adef08a767de>", line 6
#     .drop(columns='val_updated')\
#                                   ^
# SyntaxError: unexpected character after line continuation character

# %% [markdown]
# ## The Penny Drops
# I like those "penny dropping" moments, when you realize you knew everything that is presented, yet it is presented in a new way you never thought of.

# %%
# We can split these value inside ()
users = (134856, 195373, 295817, 294003, 262166, 121066, 129678, 307120, 258759, 277922, 220794, 192312,
         318486, 314631, 306448, 297059,206892,       
         169046, 181703, 146200, 199876, 247904, 250884, 282989, 234280, 202520,       
         138064, 133577, 301053, 242157)

# %%
# Penny Drop: We can also Split here
df = (df_io
        .copy() # This is an inline comment
        # This is a regular comment
        .sort_values('date_')
        .set_index('date_')
        .drop(columns='val_updated')   
)

df.head()
# Out:
#                                   bear_type
# date_
# 2018-10-09 17:01:30.662389+00:00          5
# 2018-10-09 17:01:30.687675+00:00          5
# 2018-10-09 17:03:23.952847+00:00          1
# 2018-10-09 17:05:42.327744+00:00          7
# 2018-10-09 17:06:29.708909+00:00          7

# %% [markdown]
# ## Map with dict
# A dict is a callable with $f(key) = value$, there for you can call `.map` with it. In this example I want to make int key codes into letter.

# %%
df.bear_type.map(lambda x: x+3).head()
# Out:
# date_
# 2018-10-09 17:01:30.662389+00:00     8
# 2018-10-09 17:01:30.687675+00:00     8
# 2018-10-09 17:03:23.952847+00:00     4
# 2018-10-09 17:05:42.327744+00:00    10
# 2018-10-09 17:06:29.708909+00:00    10
# Name: bear_type, dtype: int64

# %%
# A dict is also a callable
bears = {
    1: 'Grizzly',
    2: 'Sun',
    3: 'Pizzly',
    4: 'Sloth',
    5: 'Polar',
    6: 'Cave',
    7: 'Black',
    8: 'Panda'
}
df['bear_type'] = df.bear_type.map(bears)
df.head()
# Out:
#                                  bear_type
# date_
# 2018-10-09 17:01:30.662389+00:00     Polar
# 2018-10-09 17:01:30.687675+00:00     Polar
# 2018-10-09 17:03:23.952847+00:00   Grizzly
# 2018-10-09 17:05:42.327744+00:00     Black
# 2018-10-09 17:06:29.708909+00:00     Black

# %% [markdown]
# # Time Series

# %% [markdown]
# ## Resample
# Task: How many events happen each hour?

# %% [markdown]
# ### The Old Way

# %%
bad = df.copy()
bad['day'] = bad.index.date
bad['hour'] = bad.index.hour
(bad
.groupby(['day','hour'])
.count()
)
# Out:
#                  bear_type
# day        hour
# 2018-10-09 17           83
#            18           96
#            20           91
#            21           71
#            22           84

# %% [markdown]
# * Many lines of code
# * unneeded columns
# * Index is not a time anymore
# * **missing rows** (Did you notice?)

# %% [markdown]
# ### A Better Way

# %%
df.resample('H').count() # H is for Hour
# Out:
#                            bear_type
# date_
# 2018-10-09 17:00:00+00:00         83
# 2018-10-09 18:00:00+00:00         96
# 2018-10-09 19:00:00+00:00          0
# 2018-10-09 20:00:00+00:00         91
# 2018-10-09 21:00:00+00:00         71
# 2018-10-09 22:00:00+00:00         84

# %% [markdown]
# But it's even better on non-round intervals

# %%
rs = df.resample('10T').count()
# T is for Minute, and pandas understands 10 T, it will also under stand 11T if you wonder
rs.head()
# Out:
#                            bear_type
# date_
# 2018-10-09 17:00:00+00:00          7
# 2018-10-09 17:10:00+00:00         12
# 2018-10-09 17:20:00+00:00         16
# 2018-10-09 17:30:00+00:00         13
# 2018-10-09 17:40:00+00:00         15

# %% [markdown]
# [Complete list of Pandas' time abbrevations](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Period.strftime.html)

# %% [markdown]
# ## Slice Easily
# Pandas will automatically make string into timestamps, and it will understand what you want it to do.

# %%
# Take only timestamp in the hour of 21:00.
rs.loc['2018-10-09 21',:]
# Out:
#                            bear_type
# date_
# 2018-10-09 21:00:00+00:00         11
# 2018-10-09 21:10:00+00:00         18
# 2018-10-09 21:20:00+00:00         16
# 2018-10-09 21:30:00+00:00          9
# 2018-10-09 21:40:00+00:00          7
# 2018-10-09 21:50:00+00:00         10

# %%
# Take all time stamps before 18:31
rs.loc[:'2018-10-09 18:31',:]
# Out:
#                            bear_type
# date_
# 2018-10-09 17:00:00+00:00          7
# 2018-10-09 17:10:00+00:00         12
# 2018-10-09 17:20:00+00:00         16
# 2018-10-09 17:30:00+00:00         13
# 2018-10-09 17:40:00+00:00         15
# 2018-10-09 17:50:00+00:00         20
# 2018-10-09 18:00:00+00:00         21
# 2018-10-09 18:10:00+00:00         22
# 2018-10-09 18:20:00+00:00          4
# 2018-10-09 18:30:00+00:00         19

# %% [markdown]
# ## Time Windows: Rolling, Expanding, EWM
# If your Dataframe is indexed on a time index (Which we have)

# %%
fig, ax = plt.subplots()
rs.rename(columns = {'bear_type':'bears'}).plot(ax=ax,linestyle='--')
(rs
 .rolling('90T')
 .mean()
 .rename(columns = {'bear_type':'rolling mean'})
 .plot(ax=ax)
)

rs.expanding().mean().rename(columns = {'bear_type':'expanding mean'}).plot(ax=ax)
rs.ewm(6).mean().rename(columns = {'bear_type':'ewm mean'}).plot(ax=ax)
plt.show()

# %% [markdown]
# ### With Apply
# Intuitively, windows are like GroupBy, so you can apply anything you want after the grouping, e.g.: geometric mean.

# %%
fig, ax = plt.subplots()
rs.plot(ax=ax,linestyle='--')
(rs
 .rolling(6)
 .apply(lambda x: np.power(np.product(x),1/len(x)),raw=True)
 .rename(columns = {'bear_type':'Rolling Geometric Mean'})
 .plot(ax=ax)
)
plt.show()

# %% [markdown]
# ## Combine with GroupBy 🤯
# Pandas has no problem with groupby and resample together. It's as simple as `groupby[col1,col2]`. In our specific case, we want to cound events in an interval per event type.

# %%
per_bear = (df
             .groupby('bear_type')
             .resample('15T')
             .apply('count')
             .rename(columns={'bear_type':'amount'})
            )
per_bear.groupby('bear_type').head(2)
# Out:
#                                      amount
# bear_type date_
# Black     2018-10-09 17:00:00+00:00       2
#           2018-10-09 17:15:00+00:00       4
# Grizzly   2018-10-09 17:00:00+00:00       8
#           2018-10-09 17:15:00+00:00       6
# Polar     2018-10-09 17:00:00+00:00       4
#           2018-10-09 17:15:00+00:00      11

# %% [markdown]
# # Sorting

# %% [markdown]
# ## By Values

# %%
per_bear.sort_values(by=['amount'], ascending=False).head(10)
# Out:
#                                      amount
# bear_type date_
# Polar     2018-10-09 18:00:00+00:00      18
#           2018-10-09 20:30:00+00:00      17
#           2018-10-09 18:30:00+00:00      16
#           2018-10-09 22:45:00+00:00      14
#           2018-10-09 22:30:00+00:00      12
# Grizzly   2018-10-09 18:45:00+00:00      12
# Black     2018-10-09 20:30:00+00:00      12
# Grizzly   2018-10-09 20:45:00+00:00      12
# Polar     2018-10-09 22:00:00+00:00      12
# Grizzly   2018-10-09 22:15:00+00:00      11

# %% [markdown]
# ## By Index

# %%
per_bear.sort_index().head(7)
# Out:
#                                      amount
# bear_type date_
# Black     2018-10-09 17:00:00+00:00       2
#           2018-10-09 17:15:00+00:00       4
#           2018-10-09 17:30:00+00:00       4
#           2018-10-09 17:45:00+00:00      10
#           2018-10-09 18:00:00+00:00       7
#           2018-10-09 18:15:00+00:00       6
#           2018-10-09 18:30:00+00:00       8

# %%
per_bear.sort_index(level=1).head(7)
# Out:
#                                      amount
# bear_type date_
# Black     2018-10-09 17:00:00+00:00       2
# Grizzly   2018-10-09 17:00:00+00:00       8
# Polar     2018-10-09 17:00:00+00:00       4
# Black     2018-10-09 17:15:00+00:00       4
# Grizzly   2018-10-09 17:15:00+00:00       6
# Polar     2018-10-09 17:15:00+00:00      11
# Black     2018-10-09 17:30:00+00:00       4

# %% [markdown]
# ## By Both <span style="color:red">(New in 0.23)</span>
# `Index` has a name. Modern Pandas knows to address this index by name just like a regular column.

# %%
per_bear.sort_values(['amount','bear_type'], ascending=(False, True)).head(10)
# Out:
#                                      amount
# bear_type date_
# Polar     2018-10-09 18:00:00+00:00      18
#           2018-10-09 20:30:00+00:00      17
#           2018-10-09 18:30:00+00:00      16
#           2018-10-09 22:45:00+00:00      14
# Black     2018-10-09 20:30:00+00:00      12
# Grizzly   2018-10-09 18:45:00+00:00      12
#           2018-10-09 20:45:00+00:00      12
# Polar     2018-10-09 22:00:00+00:00      12
#           2018-10-09 22:30:00+00:00      12
# Grizzly   2018-10-09 22:15:00+00:00      11

# %% [markdown]
# # Stack, Unstack

# %% [markdown]
# ## Unstack
# In this case, working with a wide format indexed on intervals, with event types as columns, will make a lot more sense.

# %% [markdown]
# ### The Old way
# Pivot table in modern pandas is more robust than it used to be. Still, it requires you to specify everything.

# %%
pt = pd.pivot_table(per_bear,values = 'amount',columns='bear_type',index='date_')
pt.head()
# Out:
# bear_type                  Black  Grizzly  Polar
# date_
# 2018-10-09 17:00:00+00:00      2        8      4
# 2018-10-09 17:15:00+00:00      4        6     11
# 2018-10-09 17:30:00+00:00      4        6      9
# 2018-10-09 17:45:00+00:00     10        9     10
# 2018-10-09 18:00:00+00:00      7        3     18

# %% [markdown]
# ### A better way
# When you have just one column of values, unstack does the same easily

# %%
pt = per_bear.unstack('bear_type')
pt.columns = pt.columns.droplevel() # Unstack creates a multiindex on columns
pt.head()
# Out:
# bear_type                  Black  Grizzly  Polar
# date_
# 2018-10-09 17:00:00+00:00      2        8      4
# 2018-10-09 17:15:00+00:00      4        6     11
# 2018-10-09 17:30:00+00:00      4        6      9
# 2018-10-09 17:45:00+00:00     10        9     10
# 2018-10-09 18:00:00+00:00      7        3     18

# %% [markdown]
# ## Unstack
# And some extra tricks

# %%
pt.stack().head()
# Out:
# date_                      bear_type
# 2018-10-09 17:00:00+00:00  Black        2
#                            Grizzly      8
#                            Polar        4
# 2018-10-09 17:15:00+00:00  Black        4
#                            Grizzly      6
# dtype: int64

# %% [markdown]
# This looks kind of what we had expected but:
# * It's a series, not a DataFrame
# * The levels of the index are "reversed" to before
# * The main sort is on the date, yet it used to be on the event type
#
#
# ### Some More Hacks

# %%
stack_back = (pt
              .stack()
              .to_frame('amount') # Turn Series to DF without calling the DF constructor
              .swaplevel() # Swaps the levels of the index
              .sort_index()
             )
stack_back.head()
# Out:
#                                      amount
# bear_type date_
# Black     2018-10-09 17:00:00+00:00       2
#           2018-10-09 17:15:00+00:00       4
#           2018-10-09 17:30:00+00:00       4
#           2018-10-09 17:45:00+00:00      10
#           2018-10-09 18:00:00+00:00       7

# %%
stack_back.equals(per_bear)
# Out:
# True

# %% [markdown]
# # GroupBy

# %% [markdown]
# ```sql
# select min(B), avg(B), geometric_mean(B), min(C), max(C)
# from pt
# group by A
# ```

# %%
pt
# Out:
# bear_type                  Black  Grizzly  Polar
# date_
# 2018-10-09 17:00:00+00:00      2        8      4
# 2018-10-09 17:15:00+00:00      4        6     11
# 2018-10-09 17:30:00+00:00      4        6      9
# 2018-10-09 17:45:00+00:00     10        9     10
# 2018-10-09 18:00:00+00:00      7        3     18
# 2018-10-09 18:15:00+00:00      6        2     11
# 2018-10-09 18:30:00+00:00      8        1     16
# 2018-10-09 18:45:00+00:00      3       12      9
# 2018-10-09 19:00:00+00:00      0        0      0
# 2018-10-09 19:15:00+00:00      0        0      0
# 2018-10-09 19:30:00+00:00      0        0      0
# 2018-10-09 19:45:00+00:00      0        0      0
# 2018-10-09 20:00:00+00:00      4        2      7
# 2018-10-09 20:15:00+00:00      5        1      7
# 2018-10-09 20:30:00+00:00     12        8     17
# 2018-10-09 20:45:00+00:00      7       12      9
# 2018-10-09 21:00:00+00:00      9        7      7
# 2018-10-09 21:15:00+00:00      8        5      9
# 2018-10-09 21:30:00+00:00      3        2      7
# 2018-10-09 21:45:00+00:00      3        1     10
# 2018-10-09 22:00:00+00:00      4       10     12
# 2018-10-09 22:15:00+00:00      4       11      7
# 2018-10-09 22:30:00+00:00      4        2     12
# 2018-10-09 22:45:00+00:00      3        1     14

# %% [markdown]
# ## Old Ways

# %%
pt.groupby('Grizzly')['Polar'].agg(['min','mean']).head()
# Out:
#          min   mean
# Grizzly
# 0          0   0.00
# 1          7  11.75
# 2          7   9.25
# 3         18  18.00
# 5          9   9.00

# %% [markdown]
# ### List Aggregates

# %%
pt.groupby('Grizzly')[['Polar','Black']].agg(['min','mean',lambda x: x.prod()/len(x),'max']).head()
# Out:
#         Polar                       Black
#           min   mean <lambda_0> max   min  mean <lambda_0> max
# Grizzly
# 0           0   0.00        0.0   0     0  0.00        0.0   0
# 1           7  11.75     3920.0  16     3  4.75       90.0   8
# 2           7   9.25     1617.0  12     3  4.25       72.0   6
# 3          18  18.00       18.0  18     7  7.00        7.0   7
# 5           9   9.00        9.0   9     8  8.00        8.0   8

# %% [markdown]
# * Not what we wanted
# * MultiIndex
# * Names are not unique
# * How do you access `<lambda_0>`

# %% [markdown]
# ### Dict aggregate

# %%
pt.groupby('Grizzly').agg({'Polar':['min','mean',lambda x: x.prod()/len(x)],'Black':['min','max']})
# Out:
#         Polar                   Black
#           min   mean <lambda_0>   min max
# Grizzly
# 0           0   0.00        0.0     0   0
# 1           7  11.75     3920.0     3   8
# 2           7   9.25     1617.0     3   6
# 3          18  18.00       18.0     7   7
# 5           9   9.00        9.0     8   8
# 6           9  10.00       49.5     4   4
# 7           7   7.00        7.0     9   9
# 8           4  10.50       34.0     2  12
# 9          10  10.00       10.0    10  10
# 10         12  12.00       12.0     4   4
# 11          7   7.00        7.0     4   4
# 12          9   9.00       40.5     3   7

# %% [markdown]
# ### With Rename

# %%
pt.groupby('Grizzly').Polar.agg({'min_Polar':'min'})
# Out:
#          min_Polar
# Grizzly
# 0                0
# 1                7
# 2                7
# 3               18
# 5                9
# 6                9
# 7                7
# 8                4
# 9               10
# 10              12
# 11               7
# 12               9

# %%
warnings.simplefilter("ignore")
pt.groupby('Grizzly').agg({
    'Polar':{'min_Polar':'min','avg_Polar':'mean','geo_Polar':lambda x: x.prod()/len(x)},
    'Black':{'min_Black':'min','max_Black':'max'}
    
})
warnings.simplefilter("default")

# %% [markdown]
# Still a MultiIndex

# %% [markdown]
# ## Named Aggregations <span style="color:red">(New in 0.25)</span>
# This is also the way to go from `1.0.0` as others will be depracated

# %%
def geo(x):
    return x.prod()/len(x)

# %%
pt.groupby('Grizzly').agg(
    min_Polar = pd.NamedAgg(column='Polar', aggfunc='min'),
    avg_Polar = pd.NamedAgg(column='Polar', aggfunc='mean'),
    geo_Polar = pd.NamedAgg('Polar', geo),
    # But actually NamedAgg is optional
    min_Black = ('Black','min'),
    max_Black = ('Black','max')
    
)
# Out:
#          min_Polar  avg_Polar  geo_Polar  min_Black  max_Black
# Grizzly
# 0                0       0.00        0.0          0          0
# 1                7      11.75     3920.0          3          8
# 2                7       9.25     1617.0          3          6
# 3               18      18.00       18.0          7          7
# 5                9       9.00        9.0          8          8
# 6                9      10.00       49.5          4          4
# 7                7       7.00        7.0          9          9
# 8                4      10.50       34.0          2         12
# 9               10      10.00       10.0         10         10
# 10              12      12.00       12.0          4          4
# 11               7       7.00        7.0          4          4
# 12               9       9.00       40.5          3          7

# %% [markdown]
# # Clip
# Let's say, we know from domain knowledge the that an bear walks around a minimum of 3 and maximum of 12 times at each timestamp. We would like to fix that.
# In a real world example, we many time want to turn negative numbers to zeroes or some truly big numbers to sum known max.

# %% [markdown]
# ## The Old Way
# Iterate over columns and change values that meet condition.

# %%
cl = pt.copy()
lb = 3
ub = 12
# Needed A loop of 3 lines
for col in ['Grizzly','Polar','Black']:
    cl['clipped_{}'.format(col)] = cl[col]
    cl.loc[cl[col] < lb,'clipped_{}'.format(col)] = lb
    cl.loc[cl[col] > ub,'clipped_{}'.format(col)] = ub
my_utils.plot_clipped(cl) # my_utils can be found in the github repo

# %% [markdown]
# ## A better way
# `.clip(lb,ub)`

# %%
cl = pt.copy()
cl['Grizzly'] = cl.Grizzly.clip(3,12)

# %%
cl = pt.copy()
# Beutiful One Liner
cl[['clipped_Grizzly','clipped_Polar','clipped_Black']] = cl.clip(5,12)
my_utils.plot_clipped(cl) # my_utils can be found in the github repo

# %% [markdown]
# # Reindex
# Now we have 3 types of bears 17:00 to 23:00. But we were at the the park from 16:00 to 00:00. We've also been told that this park as Panda bears and Cave bears.
# In the old way we would have this column assignment with a loop, and for the rows we would have maybe create a columns and do some join. A lot of work.

# %%
etypes = ['Grizzly','Polar','Black','Panda','Cave'] # New columns
# Define a date range - Pandas will automatically make this into an index
idx = pd.date_range(start='2018-10-09 16:00:00',end='2018-10-09 23:59:00',freq=pt.index.freq,tz='UTC')
type(idx)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
pt.reindex(index=idx, columns=etypes, fill_value=0).head(8)
# Out:
# bear_type                  Grizzly  Polar  Black  Panda  Cave
# 2018-10-09 16:00:00+00:00        0      0      0      0     0
# 2018-10-09 16:15:00+00:00        0      0      0      0     0
# 2018-10-09 16:30:00+00:00        0      0      0      0     0
# 2018-10-09 16:45:00+00:00        0      0      0      0     0
# 2018-10-09 17:00:00+00:00        8      4      2      0     0
# 2018-10-09 17:15:00+00:00        6     11      4      0     0
# 2018-10-09 17:30:00+00:00        6      9      4      0     0
# 2018-10-09 17:45:00+00:00        9     10     10      0     0

# %%
### Let's put this in a function - This will help us later.
def get_all_types_and_timestamps(df, min_date='2018-10-09 16:00:00',
                                 max_date='2018-10-09 23:59:00',
                                 etypes=['Grizzly','Polar','Black','Panda','Cave']):
    ret = df.copy()
    time_idx = pd.date_range(start=min_date,end=max_date,freq='15T',tz='UTC')
    # Indices work like set. This is a good practive so we don't override our intended index
    idx = ret.index.union(time_idx)
    etypes = df.columns.union(set(etypes))
    ret = ret.reindex(idx, columns=etypes, fill_value=0)
    return ret

# %% [markdown]
# # Method Chaining

# %% [markdown]
# ## Assign
# Assign is for creating new columns on the dataframes. This is instead of
# `df[new_col] = function(df[old_col])`. They are both one lines, but `.assign` doesn't break the flow.

# %%
pt.assign(mean_all = pt.mean(axis=1)).head()
# Out:
# bear_type                  Black  Grizzly  Polar  mean_all
# date_
# 2018-10-09 17:00:00+00:00      2        8      4  4.666667
# 2018-10-09 17:15:00+00:00      4        6     11  7.000000
# 2018-10-09 17:30:00+00:00      4        6      9  6.333333
# 2018-10-09 17:45:00+00:00     10        9     10  9.666667
# 2018-10-09 18:00:00+00:00      7        3     18  9.333333

# %% [markdown]
# ### With a callable
# This is good when we have a filtering phase before.

# %%
pt.assign(mean_all = lambda x: x.mean(axis=1)).head()
# Out:
# bear_type                  Black  Grizzly  Polar  mean_all
# date_
# 2018-10-09 17:00:00+00:00      2        8      4  4.666667
# 2018-10-09 17:15:00+00:00      4        6     11  7.000000
# 2018-10-09 17:30:00+00:00      4        6      9  6.333333
# 2018-10-09 17:45:00+00:00     10        9     10  9.666667
# 2018-10-09 18:00:00+00:00      7        3     18  9.333333

# %% [markdown]
# ## Pipe
# Think R's `%>%`, `.pipe` is a method that accepts a function. `pipe`, by default, assumes the first argument of this function is a dataframe and passes the current dataframe down the pipeline. The function should return a dataframe also, if you want to continue with the chaining. Yet, it can also return any other value if you put it in the last step.
# This is incredibly valueable because it takes you one step further from "sql" where you do things "in reverse".
# $f(g(h($ `df` $)))$ = `df.pipe(h).pipe(g).pipe(f)`

# %%
def add_to_col(df, col='Grizzly', n = 200):
    ret = df.copy()
    # A dataframe is mutable, if you don't copy it first, this is prone to many errors.
    # I always copy when I enter a function, even if I'm sure it shouldn't change anything.
    ret[col] = ret[col] + n
    return ret

# %%
add_to_col(add_to_col(add_to_col(pt), 'Polar', 100), 'Black',500).head()
# Out:
# bear_type                  Black  Grizzly  Polar
# date_
# 2018-10-09 17:00:00+00:00    502      208    104
# 2018-10-09 17:15:00+00:00    504      206    111
# 2018-10-09 17:30:00+00:00    504      206    109
# 2018-10-09 17:45:00+00:00    510      209    110
# 2018-10-09 18:00:00+00:00    507      203    118

# %%
(pt
  .pipe(add_to_col)
  .pipe(add_to_col, col='Polar', n=100)
  .pipe(add_to_col, col='Black', n=500)  
  .head(5))
# Out:
# bear_type                  Black  Grizzly  Polar
# date_
# 2018-10-09 17:00:00+00:00    502      208    104
# 2018-10-09 17:15:00+00:00    504      206    111
# 2018-10-09 17:30:00+00:00    504      206    109
# 2018-10-09 17:45:00+00:00    510      209    110
# 2018-10-09 18:00:00+00:00    507      203    118

# %% [markdown]
# You can always do this with multiple lines of `df = do_something(df)` but I think this method is more elegant.

# %% [markdown]
# # Beautiful Code Tells a Story
# Your code is not just about making the computer do things. It's about telling a story of what you wish to happen. Sometimes other people will want to read you code. Most time, it is you 3 monhts in the future who will want to read it. Some say good code documents itself. I'm not that extreme, yet storytelling with code may save you from many lines of unnecessary comments.
# The next and final block tells the story in one block. It's elegant, it tells a story. If you build utility functions and `pipe` them while following meaningful naming, they help tell a story. if you `assign` columns with meaningful names, they tell a story. you `drop`, you `apply`, you `read`, you `groupby` and you `resample` - they all tell a story.
#
# (Well... Maybe they could have gone with better naming for `resample`)

# %%
df = (pd
      .read_csv    ('./bear_data.csv', index_col=0, parse_dates=['date_'])
      .assign      (bear_type=lambda df: df.bear_type.map(bears))
      .sort_values ('date_')
      .set_index   ('date_')
      .drop        (columns='val_updated')
      .groupby     ('bear_type')
      .resample    ('15T')
      .apply       ('count')
      .rename      (columns={'bear_type': 'amount'})
      .unstack     ('bear_type')
      .pipe        (my_utils.remove_multi_index)
      .pipe        (get_all_types_and_timestamps) # Remember this from before?
      .assign      (mean_bears=lambda x: x.mean(axis=1))
      .loc         [:, ['mean_bears']]
      .pipe        (my_utils.make_sliding_time_windows, steps_back=6)
      .dropna      ()
      )

# %%
df.head()
# Out:
#                            mean_bears  mean_bears-1  mean_bears-2  \
# 2018-10-09 17:30:00+00:00         3.8           4.2           2.8
# 2018-10-09 17:45:00+00:00         5.8           3.8           4.2
# 2018-10-09 18:00:00+00:00         5.6           5.8           3.8
# 2018-10-09 18:15:00+00:00         3.8           5.6           5.8
# 2018-10-09 18:30:00+00:00         5.0           3.8           5.6
#
#                            mean_bears-3  mean_bears-4  mean_bears-5  \
# 2018-10-09 17:30:00+00:00           0.0           0.0           0.0
# 2018-10-09 17:45:00+00:00           2.8           0.0           0.0
# 2018-10-09 18:00:00+00:00           4.2           2.8           0.0
# 2018-10-09 18:15:00+00:00           3.8           4.2           2.8
# 2018-10-09 18:30:00+00:00           5.8           3.8           4.2
#
#                            mean_bears-6
# 2018-10-09 17:30:00+00:00           0.0
# 2018-10-09 17:45:00+00:00           0.0
# 2018-10-09 18:00:00+00:00           0.0
# 2018-10-09 18:15:00+00:00           0.0
# 2018-10-09 18:30:00+00:00           2.8

# %% [markdown]
# # Bonus!
# Cool methods I've found but did not fit in the talk's flow.
#
#
# <span style="font-size:2em"> [No Time?](#You-don't-have-to-memorize-this)</span>

# %%
src = df.copy().loc[:,['mean_bears']]

# %% [markdown]
# ## Percent Change

# %%
src.assign(pct = src.pct_change()).head(11)
# Out:
#                            mean_bears       pct
# 2018-10-09 17:30:00+00:00         3.8       NaN
# 2018-10-09 17:45:00+00:00         5.8  0.526316
# 2018-10-09 18:00:00+00:00         5.6 -0.034483
# 2018-10-09 18:15:00+00:00         3.8 -0.321429
# 2018-10-09 18:30:00+00:00         5.0  0.315789
# 2018-10-09 18:45:00+00:00         4.8 -0.040000
# 2018-10-09 19:00:00+00:00         0.0 -1.000000
# 2018-10-09 19:15:00+00:00         0.0       NaN
# 2018-10-09 19:30:00+00:00         0.0       NaN
# 2018-10-09 19:45:00+00:00         0.0       NaN
# 2018-10-09 20:00:00+00:00         2.6       inf

# %% [markdown]
# ## Interval Index
# Helps creating a "common language" when talking about time series aggregations.

# %%
src = df.copy()
ir = pd.interval_range(start=df.index.min(),
                       end=df.index.max() + df.index.freq,
                       freq=df.index.freq)
type(ir)
# Out:
# pandas.core.indexes.interval.IntervalIndex

# %%
ir
# Out:
# IntervalIndex([(2018-10-09 17:30:00, 2018-10-09 17:45:00], (2018-10-09 17:45:00, 2018-10-09 18:00:00], (2018-10-09 18:00:00, 2018-10-09 18:15:00], (2018-10-09 18:15:00, 2018-10-09 18:30:00], (2018-10-09 18:30:00, 2018-10-09 18:45:00] ... (2018-10-09 22:45:00, 2018-10-09 23:00:00], (2018-10-09 23:00:00, 2018-10-09 23:15:00], (2018-10-09 23:15:00, 2018-10-09 23:30:00], (2018-10-09 23:30:00, 2018-10-09 23:45:00], (2018-10-09 23:45:00, 2018-10-10]],
#               closed='right',
#               dtype='interval[datetime64[ns, UTC]]')

# %%
try:
    df.loc['2018-10-09 18:37',:] # Datetime Index
except Exception as e:
    print (type(e), e)
# Will result error
# Out:
# <class 'KeyError'> '2018-10-09 18:37'

# %%
src.index = ir # Interval Index
src.loc['2018-10-09 18:37',:]
# Out:
# mean_bears      5.0
# mean_bears-1    3.8
# mean_bears-2    5.6
# mean_bears-3    5.8
# mean_bears-4    3.8
# mean_bears-5    4.2
# mean_bears-6    2.8
# Name: (2018-10-09 18:30:00, 2018-10-09 18:45:00], dtype: float64

# %%
src.loc['2018-10-09 18:37':'2018-10-09 19:03',:]
# Out:
#                                             mean_bears  mean_bears-1  \
# (2018-10-09 18:30:00, 2018-10-09 18:45:00]         5.0           3.8
# (2018-10-09 18:45:00, 2018-10-09 19:00:00]         4.8           5.0
# (2018-10-09 19:00:00, 2018-10-09 19:15:00]         0.0           4.8
#
#                                             mean_bears-2  mean_bears-3  \
# (2018-10-09 18:30:00, 2018-10-09 18:45:00]           5.6           5.8
# (2018-10-09 18:45:00, 2018-10-09 19:00:00]           3.8           5.6
# (2018-10-09 19:00:00, 2018-10-09 19:15:00]           5.0           3.8
#
#                                             mean_bears-4  mean_bears-5  \
# (2018-10-09 18:30:00, 2018-10-09 18:45:00]           3.8           4.2
# (2018-10-09 18:45:00, 2018-10-09 19:00:00]           5.8           3.8
# (2018-10-09 19:00:00, 2018-10-09 19:15:00]           5.6           5.8
#
#                                             mean_bears-6
# (2018-10-09 18:30:00, 2018-10-09 18:45:00]           2.8
# (2018-10-09 18:45:00, 2018-10-09 19:00:00]           4.2
# (2018-10-09 19:00:00, 2018-10-09 19:15:00]           3.8

# %% [markdown]
# ## Split Strings
# The entire concept of strings is different in `1.0.0`

# %%
txt = pd.DataFrame({'text':['hello','dean langsam','diving into pandas is better than reinventing it']})

txt
# Out:
#                                                text
# 0                                             hello
# 1                                      dean langsam
# 2  diving into pandas is better than reinventing it

# %%
txt.text.str.split()
# Out:
# 0                                              [hello]
# 1                                      [dean, langsam]
# 2    [diving, into, pandas, is, better, than, reinv...
# Name: text, dtype: object

# %%
txt.text.str.split(expand = True) # Expand to make it a dataframe
# Out:
#         0        1       2     3       4     5            6     7
# 0   hello     None    None  None    None  None         None  None
# 1    dean  langsam    None  None    None  None         None  None
# 2  diving     into  pandas    is  better  than  reinventing    it

# %% [markdown]
# ## Toy Examples with Pandas Testing

# %%
import pandas.util.testing as tm
tm.N, tm.K = 15, 10
st = pd.util.testing.makeTimeDataFrame() * 100
st
# Out:
#                      A           B           C           D           E  \
# 2000-01-03   76.648243  139.028077  -57.071292  -93.492058  -63.619847
# 2000-01-04    1.819754    3.067965 -291.074893    6.827081 -140.586636
# 2000-01-05  180.151935 -196.723819 -148.565136  -67.904139  -54.979100
# 2000-01-06   28.189153 -189.129333  -81.555059  188.679704  -72.278284
# 2000-01-07 -101.668482  -32.862569   28.577849  -60.732083  -58.077915
# 2000-01-10 -112.309137   29.584542   -0.168423   44.174891  -77.395384
# 2000-01-11  -21.797915  209.168995   11.053764   30.077252   92.280045
# 2000-01-12   65.559167 -204.932736   -8.814131   75.089533  -63.540433
# 2000-01-13  -74.265581  -82.668362  -43.748598  116.044144  -52.551520
# 2000-01-14 -134.623288 -132.859691   56.548020   69.653465 -156.492214
# 2000-01-17  -14.754729   55.649032   -0.700413  104.528622    9.544130
# 2000-01-18 -163.766211  -58.310943  -18.197637   32.695316  125.857350
# 2000-01-19    7.230236 -221.634473  -35.238478  -58.972485  -12.925738
# 2000-01-20  -51.288650  -35.148161  -22.255781  123.734014  -51.504584
# 2000-01-21  247.364781  118.099295   60.128466  177.250029 -123.850683
#
#                      F           G           H           I           J
# 2000-01-03   51.076074   -0.570278   21.054169 -170.558140   24.413002
# 2000-01-04  -69.092276 -110.405468 -105.751893  -19.874985   78.484417
# 2000-01-05   27.051578  -30.977013  207.842006  -41.913724  170.377617
# 2000-01-06   19.388831  103.535634  -18.090410   25.307475  -71.655466
# 2000-01-07  -32.682636   -0.986512  100.786592    2.786498  131.150870
# 2000-01-10 -132.680874  -20.910827   74.050487  -33.674917 -148.956941
# 2000-01-11   45.717764  103.741438  114.185018  -91.941836 -140.443386
# 2000-01-12  -27.003115  -30.034435   73.978500 -104.910940   24.918856
# 2000-01-13   -2.888528  123.266405 -119.245909   68.202143   46.633736
# 2000-01-14  -63.233393   72.875835  114.501544  -86.757137   32.471299
# 2000-01-17  -37.453273    9.578634  -18.094185  133.135209    0.999581
# 2000-01-18  -42.890693  -98.360557  138.283384  -82.535372    8.858450
# 2000-01-19  -90.289888   26.479575   11.530062  -30.115008 -148.479362
# 2000-01-20   -8.229897    7.209174  -81.702780 -160.877364  -90.794033
# 2000-01-21   32.416456  -58.986173   24.485853  -36.190455  106.018667

# %% [markdown]
# # Research with Style!
# ![so fetch](https://media.giphy.com/media/G6ojXggFcXWCs/giphy.gif)

# %%
stnan = st.copy()
stnan[np.random.rand(*stnan.shape) < 0.05] = np.nan # Put some nans in it

# %% [markdown]
# ## Basic

# %%
(stnan
 .style
 .highlight_null('red')
 .highlight_max(color='steelblue', axis = 0) # Max each row
 .highlight_min(color ='gold', axis = 1) # Min each columns
)
# Out:
# /Users/deanl/anaconda3/envs/dont/lib/python3.7/site-packages/jinja2/utils.py:485: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import MutableMapping
# /Users/deanl/anaconda3/envs/dont/lib/python3.7/site-packages/jinja2/runtime.py:318: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Mapping
# <style  type="text/css" >
#     #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row0_col5 {
#             : ;
#             background-color:  steelblue;
#             : ;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row0_col8 {
#             : ;
#             : ;
#             background-color:  gold;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row1_col0 {
#             background-color:  red;
#             : ;
#             : ;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row1_col2 {
#             : ;
#             : ;
#             background-color:  gold;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row1_col5 {
#             background-color:  red;
#             : ;
#             : ;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row2_col1 {
#             : ;
#             : ;
#             background-color:  gold;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row2_col7 {
#             : ;
#             background-color:  steelblue;
#             : ;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row2_col9 {
#             : ;
#             background-color:  steelblue;
#             : ;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row3_col1 {
#             : ;
#             : ;
#             background-color:  gold;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row3_col3 {
#             : ;
#             background-color:  steelblue;
#             : ;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row3_col8 {
#             background-color:  red;
#             : ;
#             : ;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row4_col0 {
#             : ;
#             : ;
#             background-color:  gold;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row4_col5 {
#             background-color:  red;
#             : ;
#             : ;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row5_col3 {
#             background-color:  red;
#             : ;
#             : ;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row5_col5 {
#             background-color:  red;
#             : ;
#             : ;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row5_col9 {
#             : ;
#             : ;
#             background-color:  gold;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row6_col1 {
#             : ;
#             background-color:  steelblue;
#             : ;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row6_col9 {
#             : ;
#             : ;
#             background-color:  gold;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row7_col1 {
#             : ;
#             : ;
#             background-color:  gold;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row7_col3 {
#             background-color:  red;
#             : ;
#             : ;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row8_col6 {
#             : ;
#             background-color:  steelblue;
#             : ;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row8_col7 {
#             : ;
#             : ;
#             background-color:  gold;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row9_col4 {
#             : ;
#             : ;
#             background-color:  gold;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row10_col5 {
#             : ;
#             : ;
#             background-color:  gold;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row10_col8 {
#             : ;
#             background-color:  steelblue;
#             : ;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row11_col0 {
#             : ;
#             : ;
#             background-color:  gold;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row11_col4 {
#             : ;
#             background-color:  steelblue;
#             : ;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row12_col1 {
#             : ;
#             : ;
#             background-color:  gold;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row13_col8 {
#             : ;
#             : ;
#             background-color:  gold;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row14_col0 {
#             : ;
#             background-color:  steelblue;
#             : ;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row14_col2 {
#             : ;
#             background-color:  steelblue;
#             : ;
#         }    #T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row14_col4 {
#             : ;
#             : ;
#             background-color:  gold;
#         }</style><table id="T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>        <th class="col_heading level0 col5" >F</th>        <th class="col_heading level0 col6" >G</th>        <th class="col_heading level0 col7" >H</th>        <th class="col_heading level0 col8" >I</th>        <th class="col_heading level0 col9" >J</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0level0_row0" class="row_heading level0 row0" >2000-01-03 00:00:00</th>
#                         <td id="T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row0_col0" class="data row0 col0" >76.6482</td>
#                         <td id="T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row0_col1" class="data row0 col1" >139.028</td>
#                         <td id="T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row0_col2" class="data row0 col2" >-57.0713</td>
#                         <td id="T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row0_col3" class="data row0 col3" >-93.4921</td>
#                         <td id="T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row0_col4" class="data row0 col4" >-63.6198</td>
#                         <td id="T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row0_col5" class="data row0 col5" >51.0761</td>
#                         <td id="T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row0_col6" class="data row0 col6" >-0.570278</td>
#                         <td id="T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row0_col7" class="data row0 col7" >21.0542</td>
#                         <td id="T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row0_col8" class="data row0 col8" >-170.558</td>
#                         <td id="T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row0_col9" class="data row0 col9" >24.413</td>
#             </tr>
#             <tr>
#                         <th id="T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0level0_row1" class="row_heading level0 row1" >2000-01-04 00:00:00</th>
#                         <td id="T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row1_col0" class="data row1 col0" >nan</td>
#                         <td id="T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row1_col1" class="data row1 col1" >3.06796</td>
#                         <td id="T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row1_col2" class="data row1 col2" >-291.075</td>
#                         <td id="T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row1_col3" class="data row1 col3" >6.82708</td>
#                         <td id="T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row1_col4" class="data row1 col4" >-140.587</td>
#                         <td id="T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row1_col5" class="data row1 col5" >nan</td>
#                         <td id="T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row1_col6" class="data row1 col6" >-110.405</td>
#                         <td id="T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row1_col7" class="data row1 col7" >-105.752</td>
#                         <td id="T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row1_col8" class="data row1 col8" >-19.875</td>
#                         <td id="T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row1_col9" class="data row1 col9" >78.4844</td>
#             </tr>
#             <tr>
#                         <th id="T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0level0_row2" class="row_heading level0 row2" >2000-01-05 00:00:00</th>
#                         <td id="T_e60f5e54_4ffd_11ea_90d6_3af9d3ba25a0row2_col0" class="data row2 col0" >180.152</td>

# %% [markdown]
# ## Gradient

# %%
st.clip(0,100).style.background_gradient( cmap='Purples')
# Out:
# <style  type="text/css" >
#     #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row0_col0 {
#             background-color:  #674ba0;
#             color:  #f1f1f1;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row0_col1 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row0_col2 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row0_col3 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row0_col4 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row0_col5 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row0_col6 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row0_col7 {
#             background-color:  #e1e0ee;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row0_col8 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row0_col9 {
#             background-color:  #dbdbec;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row1_col0 {
#             background-color:  #faf9fc;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row1_col1 {
#             background-color:  #f9f8fb;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row1_col2 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row1_col3 {
#             background-color:  #f5f4f9;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row1_col4 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row1_col5 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row1_col6 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row1_col7 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row1_col8 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row1_col9 {
#             background-color:  #64459e;
#             color:  #f1f1f1;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row2_col0 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row2_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row2_col2 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row2_col3 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row2_col4 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row2_col5 {
#             background-color:  #9793c5;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row2_col6 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row2_col7 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row2_col8 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row2_col9 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row3_col0 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row3_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row3_col2 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row3_col3 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row3_col4 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row3_col5 {
#             background-color:  #bbbbdb;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row3_col6 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row3_col7 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row3_col8 {
#             background-color:  #dadaeb;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row3_col9 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row4_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row4_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row4_col2 {
#             background-color:  #a4a1cc;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row4_col3 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row4_col4 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row4_col5 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row4_col6 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row4_col7 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row4_col8 {
#             background-color:  #f9f8fb;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row4_col9 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row5_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row5_col1 {
#             background-color:  #cfd0e6;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row5_col2 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row5_col3 {
#             background-color:  #acaad1;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row5_col4 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row5_col5 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row5_col6 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row5_col7 {
#             background-color:  #6c54a5;
#             color:  #f1f1f1;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row5_col8 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_f54d5df8_4ffd_11ea_90d6_3af9d3ba25a0row5_col9 {
#             background-color:  #fcfbfd;
#             color:  #000000;

# %% [markdown]
# ## Custom

# %%
def custom_style(val):
    if val < -100:
        return 'background-color:red'
    elif val > 100:
        return 'background-color:green'
    elif abs(val) <20:
        return 'background-color:yellow'
    else:
        return ''
st.style.applymap(custom_style)
# Out:
# <style  type="text/css" >
#     #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row0_col1 {
#             background-color: green;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row0_col6 {
#             background-color: yellow;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row0_col8 {
#             background-color: red;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row1_col0 {
#             background-color: yellow;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row1_col1 {
#             background-color: yellow;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row1_col2 {
#             background-color: red;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row1_col3 {
#             background-color: yellow;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row1_col4 {
#             background-color: red;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row1_col6 {
#             background-color: red;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row1_col7 {
#             background-color: red;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row1_col8 {
#             background-color: yellow;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row2_col0 {
#             background-color: green;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row2_col1 {
#             background-color: red;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row2_col2 {
#             background-color: red;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row2_col7 {
#             background-color: green;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row2_col9 {
#             background-color: green;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row3_col1 {
#             background-color: red;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row3_col3 {
#             background-color: green;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row3_col5 {
#             background-color: yellow;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row3_col6 {
#             background-color: green;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row3_col7 {
#             background-color: yellow;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row4_col0 {
#             background-color: red;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row4_col6 {
#             background-color: yellow;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row4_col7 {
#             background-color: green;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row4_col8 {
#             background-color: yellow;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row4_col9 {
#             background-color: green;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row5_col0 {
#             background-color: red;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row5_col2 {
#             background-color: yellow;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row5_col5 {
#             background-color: red;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row5_col9 {
#             background-color: red;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row6_col1 {
#             background-color: green;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row6_col2 {
#             background-color: yellow;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row6_col6 {
#             background-color: green;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row6_col7 {
#             background-color: green;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row6_col9 {
#             background-color: red;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row7_col1 {
#             background-color: red;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row7_col2 {
#             background-color: yellow;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row7_col8 {
#             background-color: red;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row8_col3 {
#             background-color: green;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row8_col5 {
#             background-color: yellow;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row8_col6 {
#             background-color: green;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row8_col7 {
#             background-color: red;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row9_col0 {
#             background-color: red;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row9_col1 {
#             background-color: red;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row9_col4 {
#             background-color: red;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row9_col7 {
#             background-color: green;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row10_col0 {
#             background-color: yellow;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row10_col2 {
#             background-color: yellow;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row10_col3 {
#             background-color: green;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row10_col4 {
#             background-color: yellow;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row10_col6 {
#             background-color: yellow;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row10_col7 {
#             background-color: yellow;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row10_col8 {
#             background-color: green;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row10_col9 {
#             background-color: yellow;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row11_col0 {
#             background-color: red;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row11_col2 {
#             background-color: yellow;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row11_col4 {
#             background-color: green;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row11_col7 {
#             background-color: green;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row11_col9 {
#             background-color: yellow;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row12_col0 {
#             background-color: yellow;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row12_col1 {
#             background-color: red;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row12_col4 {
#             background-color: yellow;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row12_col7 {
#             background-color: yellow;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row12_col9 {
#             background-color: red;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row13_col3 {
#             background-color: green;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row13_col5 {
#             background-color: yellow;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row13_col6 {
#             background-color: yellow;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row13_col8 {
#             background-color: red;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row14_col0 {
#             background-color: green;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row14_col1 {
#             background-color: green;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row14_col3 {
#             background-color: green;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row14_col4 {
#             background-color: red;
#         }    #T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0row14_col9 {
#             background-color: green;
#         }</style><table id="T_1a2a0694_4ffe_11ea_90d6_3af9d3ba25a0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>        <th class="col_heading level0 col5" >F</th>        <th class="col_heading level0 col6" >G</th>        <th class="col_heading level0 col7" >H</th>        <th class="col_heading level0 col8" >I</th>        <th class="col_

# %% [markdown]
# ## Bars

# %%
(st.style
 .bar(subset=['A','D'],color='steelblue')
 .bar(subset=['J'],color=['indianred','limegreen'], align='mid')
)
# Out:
# <style  type="text/css" >
#     #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,steelblue 58.5%, transparent 58.5%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row0_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row0_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.6%, limegreen 46.6%, limegreen 54.3%, transparent 54.3%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,steelblue 40.3%, transparent 40.3%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,steelblue 35.6%, transparent 35.6%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row1_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.6%, limegreen 46.6%, limegreen 71.2%, transparent 71.2%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,steelblue 83.7%, transparent 83.7%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,steelblue 9.1%, transparent 9.1%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row2_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.6%, limegreen 46.6%, limegreen 100.0%, transparent 100.0%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,steelblue 46.7%, transparent 46.7%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,steelblue 100.0%, transparent 100.0%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row3_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 24.2%, indianred 24.2%, indianred 46.6%, transparent 46.6%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,steelblue 15.1%, transparent 15.1%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,steelblue 11.6%, transparent 11.6%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row4_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.6%, limegreen 46.6%, limegreen 87.7%, transparent 87.7%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,steelblue 12.5%, transparent 12.5%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,steelblue 48.8%, transparent 48.8%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row5_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,indianred 46.6%, transparent 46.6%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,steelblue 34.5%, transparent 34.5%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row6_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,steelblue 43.8%, transparent 43.8%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row6_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 2.7%, indianred 2.7%, indianred 46.6%, transparent 46.6%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,steelblue 55.8%, transparent 55.8%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row7_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,steelblue 59.7%, transparent 59.7%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row7_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.6%, limegreen 46.6%, limegreen 54.4%, transparent 54.4%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,steelblue 21.8%, transparent 21.8%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row8_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,steelblue 74.3%, transparent 74.3%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row8_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.6%, limegreen 46.6%, limegreen 61.2%, transparent 61.2%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,steelblue 7.1%, transparent 7.1%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row9_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,steelblue 57.8%, transparent 57.8%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row9_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.6%, limegreen 46.6%, limegreen 56.8%, transparent 56.8%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row10_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,steelblue 36.2%, transparent 36.2%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row10_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,steelblue 70.2%, transparent 70.2%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row10_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.6%, limegreen 46.6%, limegreen 47.0%, transparent 47.0%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row11_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row11_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,steelblue 44.7%, transparent 44.7%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row11_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.6%, limegreen 46.6%, limegreen 49.4%, transparent 49.4%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row12_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,steelblue 41.6%, transparent 41.6%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row12_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,steelblue 12.2%, transparent 12.2%);
#         }    #T_203d3826_4ffe_11ea_90d6_3af9d3ba25a0row12_col9 {
#             width:  10em;

# %% [markdown]
# # You don't have to memorize this
# Just put this in the back of your mind and remember that modern Pandas has so many superpowers. Just remember they exist, and google them when you actually need them.
# Always, when I feel I'm insecure about Pandas, I go back to [Greg Reda](https://twitter.com/gjreda)'s [tweet](https://twitter.com/gjreda/status/1049694953687924737):

# %% [markdown]
# ![greg](./slides/tweet.jpg)

# %% [markdown]
# # Resources
# * [Modern Pandas](https://tomaugspurger.github.io/modern-1-intro.html) by Tom Augspurger
# * [Basic Time Series Manipulation with Pandas](https://towardsdatascience.com/basic-time-series-manipulation-with-pandas-4432afee64ea) by Laura Fedoruk
# * [Pandas Docs](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.clip.html). You don't have to thoroughly go over everything, just randomly open a page in the docs and you're sure to learn a new thing.
